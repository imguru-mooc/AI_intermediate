# %%
# %matplotlib inline  
# 주피터 노트북내에 그래프 그리기
import numpy as np               # numerical computing
import matplotlib.pyplot as plt  # plotting core

x = [1,2,3]
print(type(x))
x = np.array([1,2,3])
print(type(x))
y = np.array([1,2,3])

plt.plot(x,y, 'ro' )
plt.plot(x,y, 'b--' )

plt.grid(True)
plt.show()
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>

# %% [markdown]
# ### 케라스로 구현한 선형회귀

# %%
from keras.models import Sequential # 케라스의 Sequential()을 임포트
from keras.layers import Dense      # 케라스의 Dense()를 임포트
from keras import optimizers        # 케라스의 옵티마이저를 임포트
import numpy as np # Numpy를 임포트
import matplotlib.pyplot as plt

X=np.array([1,2,3,4,5]) 
Y=np.array([1,2,3,4,5]) 

model=Sequential()
model.add(Dense(1, input_dim=1, activation='linear'))
sgd=optimizers.SGD(lr=0.01)
model.compile(optimizer=sgd ,loss='mse',metrics=['accuracy'])
model.fit(X,Y, batch_size=1, epochs=100, shuffle=False)

print(model.predict(X))
plt.plot(X, Y, 'bo')
plt.plot(X, model.predict(X), 'r-')
plt.show()
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 1ms/step - loss: 16.7776 - accuracy: 0.0000e+00
# Epoch 2/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6787 - accuracy: 0.4139
# Epoch 3/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0780 - accuracy: 0.4139
# Epoch 4/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0890 - accuracy: 0.4139
# Epoch 5/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0959 - accuracy: 0.4139
# Epoch 6/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0950 - accuracy: 0.4139
# Epoch 7/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0922 - accuracy: 0.4139
# Epoch 8/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0891 - accuracy: 0.4139
# Epoch 9/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0860 - accuracy: 0.4139
# Epoch 10/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0829 - accuracy: 0.4139
# Epoch 11/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0800 - accuracy: 0.4139
# Epoch 12/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0771 - accuracy: 0.4139
# Epoch 13/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0744 - accuracy: 0.4139
# Epoch 14/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0718 - accuracy: 0.4139
# Epoch 15/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0692 - accuracy: 0.4139
# Epoch 16/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0668 - accuracy: 0.4139
# Epoch 17/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0644 - accuracy: 0.4139
# Epoch 18/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0621 - accuracy: 0.4139
# Epoch 19/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0599 - accuracy: 0.4139
# Epoch 20/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0578 - accuracy: 0.4139
# Epoch 21/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0557 - accuracy: 0.4139
# Epoch 22/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0538 - accuracy: 0.4139
# Epoch 23/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0519 - accuracy: 0.4139
# Epoch 24/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0500 - accuracy: 0.4139
# Epoch 25/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0482 - accuracy: 0.4139
# Epoch 26/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0465 - accuracy: 0.4139
# Epoch 27/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0449 - accuracy: 0.4139
# Epoch 28/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0433 - accuracy: 0.4139
# Epoch 29/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0418 - accuracy: 0.4139
# Epoch 30/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0403 - accuracy: 0.4139
# Epoch 31/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0389 - accuracy: 0.4139
# Epoch 32/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0375 - accuracy: 0.4139
# Epoch 33/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0361 - accuracy: 0.4139
# Epoch 34/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0349 - accuracy: 0.4139
# Epoch 35/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0336 - accuracy: 0.4139
# Epoch 36/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0324 - accuracy: 0.4139
# Epoch 37/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0313 - accuracy: 0.4139
# Epoch 38/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0302 - accuracy: 0.4139
# Epoch 39/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0291 - accuracy: 0.4139
# Epoch 40/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0281 - accuracy: 0.4139
# Epoch 41/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0271 - accuracy: 0.4139
# Epoch 42/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0261 - accuracy: 0.4139
# Epoch 43/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0252 - accuracy: 0.4139
# Epoch 44/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0243 - accuracy: 0.4139
# Epoch 45/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0234 - accuracy: 0.4139
# Epoch 46/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0226 - accuracy: 0.4139
# Epoch 47/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0218 - accuracy: 0.4139
# Epoch 48/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0210 - accuracy: 0.4139
# Epoch 49/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0203 - accuracy: 0.4139
# Epoch 50/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0196 - accuracy: 0.4139
# Epoch 51/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0189 - accuracy: 0.4139
# Epoch 52/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0182 - accuracy: 0.4139
# Epoch 53/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0176 - accuracy: 0.4139
# Epoch 54/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0169 - accuracy: 0.4139
# Epoch 55/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0163 - accuracy: 0.4139
# Epoch 56/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 0.4139
# Epoch 57/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0152 - accuracy: 0.4139
# Epoch 58/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0147 - accuracy: 0.4139
# Epoch 59/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0141 - accuracy: 0.4139
# Epoch 60/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0136 - accuracy: 0.4139
# Epoch 61/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0132 - accuracy: 0.4139
# Epoch 62/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0127 - accuracy: 0.4139
# Epoch 63/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0122 - accuracy: 0.4139
# Epoch 64/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0118 - accuracy: 0.4139
# Epoch 65/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0114 - accuracy: 0.4139
# Epoch 66/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0110 - accuracy: 0.4139
# Epoch 67/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0106 - accuracy: 0.4139
# Epoch 68/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0102 - accuracy: 0.4139
# Epoch 69/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0099 - accuracy: 0.4139
# Epoch 70/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0095 - accuracy: 0.4139
# Epoch 71/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0092 - accuracy: 0.4139
# Epoch 72/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0088 - accuracy: 0.4139
# Epoch 73/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0085 - accuracy: 0.4139
# Epoch 74/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0082 - accuracy: 0.4139
# Epoch 75/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0079 - accuracy: 0.4139
# Epoch 76/100
# 5/5 [==============================] - 0s 1000us/step - loss: 0.0077 - accuracy: 0.4139
# Epoch 77/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 0.4139
# Epoch 78/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0071 - accuracy: 0.4139
# Epoch 79/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.4139
# Epoch 80/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0066 - accuracy: 0.4139
# Epoch 81/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0064 - accuracy: 0.4139
# Epoch 82/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0062 - accuracy: 0.4139
# Epoch 83/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0059 - accuracy: 0.4139
# Epoch 84/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0057 - accuracy: 0.4139
# Epoch 85/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0055 - accuracy: 0.4139
# Epoch 86/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0053 - accuracy: 0.4139
# Epoch 87/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0051 - accuracy: 0.4139
# Epoch 88/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0050 - accuracy: 0.4139
# Epoch 89/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0048 - accuracy: 0.4139
# Epoch 90/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0046 - accuracy: 0.4139
# Epoch 91/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0045 - accuracy: 0.4139
# Epoch 92/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0043 - accuracy: 0.4139
# Epoch 93/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0041 - accuracy: 0.4139
# Epoch 94/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0040 - accuracy: 0.4139
# Epoch 95/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0039 - accuracy: 0.4139
# Epoch 96/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0037 - accuracy: 0.4139
# Epoch 97/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 0.4139
# Epoch 98/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0035 - accuracy: 0.4139
# Epoch 99/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0033 - accuracy: 0.4139
# Epoch 100/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 0.4139
# [[1.0758765]
#  [2.0524566]
#  [3.029037 ]
#  [4.005617 ]
#  [4.9821973]]

# %%
import numpy as np   # numeriacal computing
import matplotlib.pyplot as plt  # plotting core

# a = (3,1)
# print(type(a))

x = np.array([1,2,3])

print(type(x))
print(x.ndim)  
print(x.shape) 
print(x.shape[0])
print(len(x))

y = np.array([1,2,3])

plt.plot(x,y, 'r--' )
plt.plot(x,y, 'b.' )

plt.grid(True)
plt.show()
# Out:
# <class 'numpy.ndarray'>
# 1
# (3,)
# 3
# 3

# %%
import numpy as np   # numeriacal computing
import matplotlib.pyplot as plt  # plotting core

x = np.array([1,2,3])
y = np.array([1,2,3])

w = 0
b = 0

y_hat = np.zeros(3)
print(y_hat)
print(y_hat.shape)
print(len(y_hat))
print(y_hat.shape[0])

# for i in range(3):
#     print(i+1)

for i in range(len(x)):
    y_hat[i] = w*x[i] + b;
print(y_hat)

plt.plot(x,y, 'o' )
plt.plot(x,y, 'r-' )

plt.plot(x,y_hat, 'o' )
plt.plot(x,y_hat, 'b-' )

plt.grid(True)
plt.show()
# Out:
# [0. 0. 0.]
# (3,)
# 3
# 3
# [0. 0. 0.]

# %%
import numpy as np   # numeriacal computing
import matplotlib.pyplot as plt  # plotting core

w = np.linspace(-1,3,100)
# print(w)
# print(len(w))
b = 0

j = np.zeros(100)

for i in range(len(w)):
    y_hat = w[i]*2 + b;
    j[i] = 0.5 * (y_hat - 2)**2

plt.plot(w,j, 'o' )
plt.plot(w,j, 'r-' )

plt.grid(True)
plt.show()

# %%
import numpy as np   # numeriacal computing
import matplotlib.pyplot as plt  # plotting core

w = 1
b = np.linspace(-3,3,100)

j = np.zeros(100)
for i in range(len(b)):
    y_hat = w*2 + b[i];
    j[i] = 0.5 * (y_hat - 2)**2

plt.plot(b,j, 'o' )
plt.plot(b,j, 'r-' )

plt.grid(True)
plt.show()

# %%
import numpy as np   # numeriacal computing
import matplotlib.pyplot as plt  # plotting core

# simple function to demo step size
def f(w) : # A parabola
    f = 0.5*(w*2-2)**2
    return f
def Df(w) : # The derivative (gradient)
    Df = 2*(w*2-2)
    return Df
def xp1(w,alpha) : # update
    xp1 = w - alpha * Df(w)
    return xp1

def plot_steps( guess, alpha, nsteps) :
    fig, ax = plt.subplots()
    x = np.linspace(-1,3,100)
    ax.plot(x, f(x))
    x = guess
    ax.plot(x,f(x), 'o', label='start x=%.2f' %x )
    for i in range(nsteps):
        xold = x
        x = xp1(x,alpha)
        #ax.plot(x,f(x), 'o', label='x = %.2f' %x)
        ax.plot(x,f(x), 'o')
        ax.plot([xold,x],[f(xold),f(x)], '-')
    plt.legend()
    plt.show()
    
plot_steps( 3, 0.03, 30)

# %%
import numpy as np   # numeriacal computing
import matplotlib.pyplot as plt  # plotting core

# simple function to demo step size
def f(x) : # A parabola
    f = 0.5*x**2
    return f
def Df(x) : # The derivative (gradient)
    Df = (-x)*2
    return Df
def xp1(x,alpha) : # update
    xp1 = x + alpha * Df(x)
    return xp1

def plot_steps( guess, alpha, nsteps) :
    fig, ax = plt.subplots()
    x = np.linspace(-3,3,100)
    ax.plot(x, f(x))
    x = guess
    ax.plot(x,f(x), 'o', label='start x=%.2f' %x )
    for i in range(nsteps):
        xold = x
        x = xp1(x,alpha)
        #ax.plot(x,f(x), 'o', label='x = %.2f' %x)
        ax.plot(x,f(x), 'o')
        ax.plot([xold,x],[f(xold),f(x)], '-')
    plt.legend()
    plt.show()
    
plot_steps( 3, 0.03, 200 )

# %%
import matplotlib.pyplot as plt
import numpy as np

# The function J
def J(a0, a1, x, y, m):
    ret=0
    for i in range(m):
        ret += 0.5*((a0 + a1*x[i]) - y[i] )**2
    return ret/m

x = np.linspace(-1,1,5)
y = x

#y = np.array([0.21378624, 1.97217916, 2.36737375, 5.13718724, 6.26470731])
a0 = np.linspace(-3,3,100)
a1 = np.linspace(-3,3,100)
aa0, aa1 = np.meshgrid(a0, a1)
plt.contour(aa0,aa1,J(aa0,aa1,x,y,m=len(x)) , colors='C0', levels=[i for i in np.arange(0,80,0.3)])
plt.show()

# %%
import numpy as np
from mpl_toolkits.mplot3d.axes3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(1,1,1,projection='3d')

def pprint(arr):
    print("type:{}".format(type(arr)))
    print("shape: {}, dimension: {}, dtype:{}".format(arr.shape, arr.ndim, arr.dtype))
    print("Array's Data:\n", arr)

# The function J
def J(a0, a1, x, y, m):
    ret=0
    for i in range(m):
        ret += 0.5*((a0 + a1*x[i]) - y[i] )**2
    return ret/m

x = np.linspace(-1,1,5)
y = x
#y = np.array([0.21378624, 1.97217916, 2.36737375, 5.13718724, 6.26470731])
a0 = np.linspace(-3,3,100)
a1 = np.linspace(-3,3,100)

#pprint(x)
#pprint(y)
#pprint(a0)

#plt.plot(a1, J(a0,a1,x,y,m=len(x)) ) # set a0 to 0.1
aa0, aa1 = np.meshgrid(a0, a1)
ax.plot_surface(aa0, aa1, J(aa0,aa1,x,y,m=len(x)))

plt.show()

# %%
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()
import matplotlib.pyplot as plt
# print(type('data'))
# print(diabetes)

print(diabetes.data.shape)
print(diabetes.target.shape)
x = diabetes.data[:, 2]
# print(x)
print(x.shape)
y = diabetes.target

plt.scatter(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# (442, 10)
# (442,)
# (442,)

# %%
# a = [1,2,3]
# b = [4,5,6]
# for i in range(3):
#     print(a[i], b[i])

# a = [1,2,3]
# b = [4,5,6]
# for a_i, b_i in zip(a, b):
#     print(a_i, b_i)    

w = 1.0
b = 1.0
rate = 0.01
for x_i, y_i in zip(x, y):
    y_hat = x_i * w + b
    err = y_hat - y_i
    w = w - rate * err * x_i
    b = b - rate * err

print('w=', w)
print('b=', b)
plt.scatter(x, y)
pt1 = (-0.1, -0.1 * w + b)
pt2 = (0.15, 0.15 * w + b)
plt.plot([pt1[0], pt2[0]], [pt1[1], pt2[1]], 'r-')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# w= 9.819118656206367
# b= 151.35590713560302

# %%
rate = 0.01

for i in range(1000):
    for x_i, y_i in zip(x, y):
        y_hat = x_i * w + b
        err = y_hat - y_i 

        w = w - rate * err * x_i
        b = b - rate * err

print('w=', w)
print('b=', b)        
plt.scatter(x, y)
pt1 = (-0.1, -0.1 * w + b)
pt2 = (0.15, 0.15 * w + b)
plt.plot([pt1[0], pt2[0]], [pt1[1], pt2[1]], 'r-')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# w= 942.7435480754481
# b= 151.74601727353962

# %%
class Neuron:
    
    def __init__(self):
        self.w = 1.0     # 가중치를 초기화합니다
        self.b = 1.0     # 절편을 초기화합니다
    
    def forpass(self, x):
        y_hat = x * self.w + self.b       # 직선 방정식을 계산합니다
        return y_hat
    
    def backprop(self, x, err):
        w_grad = x * err    # 가중치에 대한 그래디언트를 계산합니다
        b_grad = 1 * err    # 절편에 대한 그래디언트를 계산합니다
        return w_grad, b_grad

    def fit(self, x, y, epochs=100, rate=0.01):
        for i in range(epochs):           # 에포크만큼 반복합니다
            for x_i, y_i in zip(x, y):    # 모든 샘플에 대해 반복합니다
                y_hat = self.forpass(x_i) # 정방향 계산
                err = y_hat - y_i      # 오차 계산
                w_grad, b_grad = self.backprop(x_i, err)  # 역방향 계산
                self.w -= rate*w_grad          # 가중치 업데이트
                self.b -= rate*b_grad          # 절편 업데이트
                
neuron = Neuron()
neuron.fit(x, y, epochs=1000)

plt.scatter(x, y)
pt1 = (-0.1, -0.1 * neuron.w + neuron.b)
pt2 = (0.15, 0.15 * neuron.w + neuron.b)
plt.plot([pt1[0], pt2[0]], [pt1[1], pt2[1]],'r')

plt.plot(0.18, 0.18 * neuron.w + neuron.b, 'ro')

plt.xlabel('x')
plt.ylabel('y')
plt.show()
